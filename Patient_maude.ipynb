# %%
import numpy as np, pandas as pd

import matplotlib.pyplot as plt, seaborn as sns
import matplotlib as mpl

import math, string, re, pickle, json, time, os, sys, datetime, itertools

from tqdm.notebook import tqdm # This makes progress bars

# %%
patientthru2022_files = pd.DataFrame()
local = False

import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)
    for year in tqdm([2022]):
        if local:
            patient = pd.read_csv('data/MAUDE_data/patientthru%d.zip' % year)
        else:
            patient = pd.read_csv('https://www.accessdata.fda.gov/MAUDE/ftparea/patientthru%d.zip' % year, sep='|', quoting=3, encoding = "ISO-8859-1", on_bad_lines='skip')
            patient.to_csv('data/MAUDE_data/patientthru%d.zip' % year, index = False)
            patientthru2022_files = patientthru2022_files.append(patient)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /var/folders/y9/lxmggbg139l2w9vkx9w8n08h0000gr/T/ipykernel_7780/541647647.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   patientthru2022_files = patientthru2022_files.append(patient)

# %%
 patientthru2022_files
# Out:
#           MDR_REPORT_KEY  PATIENT_SEQUENCE_NUMBER DATE_RECEIVED  \
# 0                     10                        1    03/10/1992
# 1                     11                        1    03/10/1992
# 2                     12                        1    03/10/1992
# 3                     13                        1    03/10/1992
# 4                     14                        1    03/10/1992
# ...                  ...                      ...           ...
# 15763969        16081268                        1    12/31/2022
# 15763970        16081269                        1    12/31/2022
# 15763971        16081270                        1    12/31/2022
# 15763972        16081271                        1    12/31/2022
# 15763973        16081272                        1    12/31/2022
#
#          SEQUENCE_NUMBER_TREATMENT SEQUENCE_NUMBER_OUTCOME
# 0                              NaN                    1. R
# 1                              NaN                    1. O
# 2                              NaN                    1. O
# 3                              NaN                    1. R
# 4                              NaN                    1. D
# ...                            ...                     ...
# 15763969                       NaN                    1. R
# 15763970                       NaN                    1. O
# 15763971                       NaN                    1. R
# 15763972       TANDEM INSULIN PUMP                    1. O
# 15763973                       NaN                     NaN
#
# [15763974 rows x 5 columns]

# %%
 patientthru2022_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15763974 entries, 0 to 15763973
# Data columns (total 5 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   MDR_REPORT_KEY             int64
#  1   PATIENT_SEQUENCE_NUMBER    int64
#  2   DATE_RECEIVED              object
#  3   SEQUENCE_NUMBER_TREATMENT  object
#  4   SEQUENCE_NUMBER_OUTCOME    object
# dtypes: int64(2), object(3)
# memory usage: 601.3+ MB

# %%
 patientthru2022_files['DATE_RECEIVED'] = pd.to_datetime( patientthru2022_files['DATE_RECEIVED']
                                                        )

# %%
 patientthru2022_files['DATE_RECEIVED'] = pd.to_datetime( patientthru2022_files['DATE_RECEIVED'], format='%Y-%m-%d')

# %%
patient_df1 = patientthru2022_files.loc[( patientthru2022_files["DATE_RECEIVED"] >= "2000-01-01") & (patientthru2022_files["DATE_RECEIVED"] < "2021-12-31")]
patient_df1
# Out:
#           MDR_REPORT_KEY  PATIENT_SEQUENCE_NUMBER DATE_RECEIVED  \
# 120350            123103                        1    2000-09-23
# 202932            206710                        1    2000-01-06
# 253286            257047                        1    2000-01-02
# 253295            257056                        1    2000-01-03
# 253328            257089                        1    2000-01-03
# ...                  ...                      ...           ...
# 14439054        14755891                        1    2014-12-09
# 14439068        14755905                        1    2014-12-11
# 15128603        15445483                        1    2019-04-01
# 15307505        15624464                        1    2013-07-09
# 15307517        15624476                        1    2013-07-09
#
#                                   SEQUENCE_NUMBER_TREATMENT  \
# 120350                                                  NaN
# 202932                                                  NaN
# 253286    1. INSULIN,; 2. INSULIN INFUSION SET, DATES OF...
# 253295                            ALPHA SOURCE LIGHT BULBS.
# 253328                                                  NaN
# ...                                                     ...
# 14439054                                                NaN
# 14439068                                                NaN
# 15128603                                                NaN
# 15307505  ALARIS PUMP MODULE AND ALARIS PC UNIT, S/N UNK...
# 15307517  ALARIS PUMP MODULE AND ALARIS PC UNIT, S/N UNK...
#
#          SEQUENCE_NUMBER_OUTCOME
# 120350                       NaN
# 202932                       NaN
# 253286                      1. H
# 253295                      1. O
# 253328                      1. O
# ...                          ...
# 14439054                     NaN
# 14439068                     NaN
# 15128603                     NaN
# 15307505                     NaN
# 15307517                     NaN
#
# [12557523 rows x 5 columns]

# %%
patient_df1["DATE_RECEIVED"].value_counts()
# Out:
# 2019-09-13    34133
# 2021-11-30    17267
# 2019-09-12    16616
# 2021-12-14    14978
# 2021-08-31    14117
#               ...
# 2014-05-04        1
# 2014-03-02        1
# 2002-09-08        1
# 2000-11-12        1
# 2000-12-02        1
# Name: DATE_RECEIVED, Length: 7901, dtype: int64

# %%
pmesh_df1 = pd.read_csv("final(2430).csv")
pmesh_df1
# Out:
#       MDR_REPORT_KEY  Unnamed: 0  EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0             263399      258173        NaN     MW1018175                  P
# 1             272787      267525        NaN     MW1018595                  P
# 2             307603      301813        NaN     MW1020521                  P
# 3             307606      301816        NaN     MW1020522                  P
# 4             307609      301819        NaN     MW1020523                  P
# ...              ...         ...        ...           ...                ...
# 2427        12975983    12672068        NaN     MW5105960                  P
# 2428        12975983    12672068        NaN     MW5105960                  P
# 2429        13002747    12698831        NaN     MW5106037                  P
# 2430        13025770    12721848        NaN     MW5106129                  P
# 2431        13118139    12814196        NaN     MW5106364                  P
#
#      MANUFACTURER_LINK_FLAG_  NUMBER_DEVICES_IN_EVENT  \
# 0                          N                      NaN
# 1                          N                      NaN
# 2                          N                      NaN
# 3                          N                      NaN
# 4                          N                      NaN
# ...                      ...                      ...
# 2427                       N                      NaN
# 2428                       N                      NaN
# 2429                       N                      NaN
# 2430                       N                      NaN
# 2431                       N                      NaN
#
#       NUMBER_PATIENTS_IN_EVENT DATE_RECEIVED ADVERSE_EVENT_FLAG  ...  \
# 0                          NaN    2000-02-16                  Y  ...
# 1                          NaN    2000-04-06                  Y  ...
# 2                          NaN    2000-11-27                  N  ...
# 3                          NaN    2000-11-27                  N  ...
# 4                          NaN    2000-11-27                  N  ...
# ...                        ...           ...                ...  ...
# 2427                       NaN    2021-12-09                  Y  ...
# 2428                       NaN    2021-12-09                  Y  ...
# 2429                       NaN    2021-12-13                  Y  ...
# 2430                       NaN    2021-12-16                  Y  ...
# 2431                       NaN    2021-12-29                  N  ...
#
#       LOT_NUMBER OTHER_ID_NUMBER DEVICE_AVAILABILITY  \
# 0          DLM02               *                   Y
# 1              *               *                   R
# 2       41K1DP03               *                   N
# 3       43GJD297               *                   N
# 4       43GJD297               *                   N
# ...          ...             ...                 ...
# 2427  0331700437             NaN                   N
# 2428  0021604246             NaN                   *
# 2429         NaN             NaN                   N
# 2430         NaN             NaN                   Y
# 2431   HUFP09919             NaN                   N
#
#      DATE_RETURNED_TO_MANUFACTURER DEVICE_REPORT_PRODUCT_CODE DEVICE_AGE_TEXT  \
# 0                              NaN                        LMO             NaN
# 1                       2000/03/15                        FZW             NaN
# 2                              NaN                        FTL             NaN
# 3                              NaN                        FTL             NaN
# 4                              NaN                        FTL             NaN
# ...                            ...                        ...             ...
# 2427                           NaN                        FTL             NaN
# 2428                           NaN                        FTL             NaN
# 2429                           NaN                        FTL             NaN
# 2430                           NaN                        FTL             NaN
# 2431                           NaN                        NAY             NaN
#
#      DEVICE_EVALUATED_BY_MANUFACTUR  COMBINATION_PRODUCT_FLAG  UDI-DI  \
# 0                               NaN                       NaN     NaN
# 1                               NaN                       NaN     NaN
# 2                               NaN                       NaN     NaN
# 3                               NaN                       NaN     NaN
# 4                               NaN                       NaN     NaN
# ...                             ...                       ...     ...
# 2427                            NaN                         N     NaN
# 2428                            NaN                         N     NaN
# 2429                            NaN                         N     NaN
# 2430                              *                         N     NaN
# 2431                            NaN                         N     NaN
#
#      UDI-PUBLIC
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2427        NaN
# 2428        NaN
# 2429        NaN
# 2430        NaN
# 2431        NaN
#
# [2432 rows x 119 columns]

# %%
pmesh_df1["DATE_RECEIVED"].value_counts()
# Out:
# 2019-09-10    44
# 2016-07-05    18
# 2017-11-30    16
# 2017-06-20    13
# 2018-01-17    12
#               ..
# 2013-02-12     1
# 2013-02-25     1
# 2013-02-20     1
# 2013-02-26     1
# 2021-12-29     1
# Name: DATE_RECEIVED, Length: 1433, dtype: int64

# %%
final_df1 = pmesh_df1.join(patient_df1, on = 'MDR_REPORT_KEY', how = 'inner', rsuffix='_device' )

final_df1
# Out:
#       MDR_REPORT_KEY  Unnamed: 0  EVENT_KEY REPORT_NUMBER REPORT_SOURCE_CODE  \
# 0             263399      258173        NaN     MW1018175                  P
# 1             272787      267525        NaN     MW1018595                  P
# 2             307603      301813        NaN     MW1020521                  P
# 3             307606      301816        NaN     MW1020522                  P
# 4             307609      301819        NaN     MW1020523                  P
# ...              ...         ...        ...           ...                ...
# 2417        12751593    12448557        NaN     MW5105132                  P
# 2418        12771109    12468070        NaN     MW5105155                  P
# 2419        12771109    12468070        NaN     MW5105155                  P
# 2420        12771284    12468245        NaN     MW5105163                  P
# 2421        12804268    12501223        NaN     MW5105281                  P
#
#      MANUFACTURER_LINK_FLAG_  NUMBER_DEVICES_IN_EVENT  \
# 0                          N                      NaN
# 1                          N                      NaN
# 2                          N                      NaN
# 3                          N                      NaN
# 4                          N                      NaN
# ...                      ...                      ...
# 2417                       N                      NaN
# 2418                       N                      NaN
# 2419                       N                      NaN
# 2420                       N                      NaN
# 2421                       N                      NaN
#
#       NUMBER_PATIENTS_IN_EVENT DATE_RECEIVED ADVERSE_EVENT_FLAG  ...  \
# 0                          NaN    2000-02-16                  Y  ...
# 1                          NaN    2000-04-06                  Y  ...
# 2                          NaN    2000-11-27                  N  ...
# 3                          NaN    2000-11-27                  N  ...
# 4                          NaN    2000-11-27                  N  ...
# ...                        ...           ...                ...  ...
# 2417                       NaN    2021-11-03                  Y  ...
# 2418                       NaN    2021-11-04                  Y  ...
# 2419                       NaN    2021-11-04                  Y  ...
# 2420                       NaN    2021-11-04                  N  ...
# 2421                       NaN    2021-11-10                  N  ...
#
#      DEVICE_AGE_TEXT DEVICE_EVALUATED_BY_MANUFACTUR COMBINATION_PRODUCT_FLAG  \
# 0                NaN                            NaN                      NaN
# 1                NaN                            NaN                      NaN
# 2                NaN                            NaN                      NaN
# 3                NaN                            NaN                      NaN
# 4                NaN                            NaN                      NaN
# ...              ...                            ...                      ...
# 2417             NaN                            NaN                        N
# 2418             NaN                            NaN                        N
# 2419             NaN                            NaN                        N
# 2420             NaN                            NaN                        N
# 2421             NaN                            NaN                        N
#
#      UDI-DI            UDI-PUBLIC MDR_REPORT_KEY_device  \
# 0       NaN                   NaN                267156
# 1       NaN                   NaN                276548
# 2       NaN                   NaN                311891
# 3       NaN                   NaN                311894
# 4       NaN                   NaN                311896
# ...     ...                   ...                   ...
# 2417    NaN                   NaN              13062381
# 2418    NaN  +$$0000SP200108220X5              13081899
# 2419    NaN  +$$0000SP200108220X5              13081899
# 2420    NaN                   NaN              13082074
# 2421    NaN                   NaN              13115065
#
#      PATIENT_SEQUENCE_NUMBER_device  DATE_RECEIVED_device  \
# 0                                 1            2000-03-01
# 1                                 1            2000-05-04
# 2                                 1            2001-01-06
# 3                                 1            2001-01-09
# 4                                 1            2001-01-09
# ...                             ...                   ...
# 2417                              1            2021-12-22
# 2418                              1            2021-12-23
# 2419                              1            2021-12-23
# 2420                              1            2021-12-23
# 2421                              1            2021-12-29
#
#                               SEQUENCE_NUMBER_TREATMENT  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2417                                                NaN
# 2418                                                NaN
# 2419                                                NaN
# 2420                                                NaN
# 2421  SMARTABLATE GEN. KIT (JAPAN); THMCL SMTCH SF B...
#
#      SEQUENCE_NUMBER_OUTCOME
# 0                        NaN
# 1                       1. O
# 2                        NaN
# 3                       1. R
# 4                       1. O
# ...                      ...
# 2417                    1. R
# 2418              1. R; 2. L
# 2419              1. R; 2. L
# 2420              1. O; 3. R
# 2421                     NaN
#
# [2422 rows x 124 columns]

# %%
final_df1["SEQUENCE_NUMBER_OUTCOME"].isnull().value_counts()
# Out:
# True     1420
# False    1002
# Name: SEQUENCE_NUMBER_OUTCOME, dtype: int64

# %%
# saving the dataframe
final_df1.to_csv('patient_mesh_text_1.csv')

# %%
final_df1["DATE_RECEIVED"].value_counts()
# Out:
# 2019-09-10    44
# 2016-07-05    18
# 2017-11-30    16
# 2017-06-20    13
# 2018-01-17    12
#               ..
# 2013-02-04     1
# 2013-02-05     1
# 2013-02-06     1
# 2013-02-12     1
# 2021-11-10     1
# Name: DATE_RECEIVED, Length: 1425, dtype: int64
